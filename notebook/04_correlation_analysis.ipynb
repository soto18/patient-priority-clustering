# %%
import sys
import pandas as pd
sys.path.insert(0, "../")

from src.preprocessing.correlation import CorrelationAnalysis

# %%
df_data = pd.read_csv("../results/preprocessing/02_dataset_preprocessing.csv")

# %%
heatmap = CorrelationAnalysis(data=df_data)
heatmap.plot_heatmap(columns=['age', 'blood pressure', 'cholesterol', 'max heart rate', 
                       'plasma glucose', 'skin_thickness', 'insulin', 'bmi'])
