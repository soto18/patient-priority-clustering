# %%
import sys
import warnings
import pandas as pd
sys.path.insert(0, "../")
warnings.filterwarnings('ignore')

from src.classification.get_plot import PerformanceMergerAndPlotter
from src.classification.plot_curves import ModelEvaluation

# %% [markdown]
# #### Performance plot

# %%
input_path = "../results/classification"
output_path = "../results/classification"
input_file = "results_exploration.csv"
output_file = "processed_performances.csv"

processor = PerformanceMergerAndPlotter(input_path=input_path, output_path=output_path)
processor.run(input_file, output_file)
# Out:
# Data loaded from ../results/classification/results_exploration.csv
# Processed data saved to ../results/classification/processed_performances.csv
# Plotting data...
# Plots generated.

# %% [markdown]
# #### ROC Curves

# %%
evaluator = ModelEvaluation("../results/classification/results_curves_exploration.csv",
                            path_export="../results/classification")
evaluator.plot_all_roc_curves()

# %% [markdown]
# #### Precision-recall curve

# %%
evaluator.plot_all_pr_curves()

# %% [markdown]
# #### Confusion_matrice

# %%
evaluator.plot_all_confusion_matrices()
